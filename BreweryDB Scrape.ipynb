# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
import time

# %%
beer_df=pd.read_csv('beer_review_ave.csv')
beer_df
# Out:
#        beer_beerid  brewery_id   review_time  review_overall  review_aroma  \
# 0                3         2.0  1.034934e+09        4.166667      4.000000
# 1                4         2.0  1.065482e+09        3.700000      3.800000
# 2                5         3.0  1.192080e+09        3.549528      3.205189
# 3                6         3.0  1.196812e+09        3.706956      3.515964
# 4                7         3.0  1.201470e+09        3.266313      3.179059
# ...            ...         ...           ...             ...           ...
# 66050        77313       185.0  1.326236e+09        3.000000      3.000000
# 66051        77314     18604.0  1.326237e+09        3.500000      3.500000
# 66052        77315     27839.0  1.326239e+09        3.500000      4.500000
# 66053        77316     20330.0  1.326252e+09        3.500000      3.500000
# 66054        77317        96.0  1.326252e+09        3.500000      3.500000
#
#        review_appearance  review_palate  review_taste  beer_abv
# ...

# %% [markdown]
# # Web Scrape of BreweryDB

# %%
#set up driver
executable_path={'executable_path': 'chromedriver.exe'}
browser= Browser('chrome', **executable_path, headless=False)
#visit breweryDB
browser.visit('https://www.brewerydb.com/')
#set search term
search ='two hearted'
#sleep to give time for page to load and to not overload the system
time.sleep(10)
#fill in search bar with beer name
browser.fill('q', search)
button=broser.find_by_text('Search')
button.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-10-16e0cc693cd5> in <module>
#       9 time.sleep(10)
#      10 #fill in search bar with beer name
# ---> 11 browser.fill('q', search)
#      12 button=broser.find_by_text('Search')
#      13 button.click()
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in fill(self, name, value)
#     566     def fill(self, name, value):
#     567         field = self.find_by_name(name).first
# --> 568         field.value = value
#     569
#     570     attach_file = fill
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in _set_value(self, value)
#     718     def _set_value(self, value):
#     719         if self._element.get_attribute("type") != "file":
# --> 720             self._element.clear()
#     721         self._element.send_keys(value)
#     722
#
# ...
