# %%
import pandas as pd

# %%
beer_reviews = pd.read_csv('beer_reviews.csv')
beer_reviews
# Out:
#          brewery_id                 brewery_name  review_time  review_overall  \
# 0             10325              Vecchio Birraio   1234817823             1.5
# 1             10325              Vecchio Birraio   1235915097             3.0
# 2             10325              Vecchio Birraio   1235916604             3.0
# 3             10325              Vecchio Birraio   1234725145             3.0
# 4              1075      Caldera Brewing Company   1293735206             4.0
# ...             ...                          ...          ...             ...
# 1586609       14359  The Defiant Brewing Company   1162684892             5.0
# 1586610       14359  The Defiant Brewing Company   1161048566             4.0
# 1586611       14359  The Defiant Brewing Company   1160702513             4.5
# 1586612       14359  The Defiant Brewing Company   1160023044             4.0
# 1586613       14359  The Defiant Brewing Company   1160005319             5.0
#
# ...

# %%
beer_review_ave = beer_reviews.groupby(['beer_beerid','beer_name','brewery_name','beer_style']).mean()
beer_review_ave
# Out:
#                                                                                                   brewery_id  \
# beer_beerid beer_name                       brewery_name                  beer_style
# 3           Cactus Queen IPA                Yellow Rose Brewing Company   American IPA                   2.0
# 4           Wildcatter's Crude Stout        Yellow Rose Brewing Company   American Stout                 2.0
# 5           Amber                           Abita Brewing Co.             Vienna Lager                   3.0
# 6           Turbodog                        Abita Brewing Co.             English Brown Ale              3.0
# 7           Purple Haze                     Abita Brewing Co.             Fruit / Vegetable Beer         3.0
# ...                                                                                                      ...
# 77313       Aass Gourmet Pale Ale           Aass Brewery                  American Blonde Ale          185.0
# ...

# %%
beer_review_ave = beer_review_ave.reset_index()
# beer_review_ave = beer_reviews.reset_index(inplace=True)
beer_review_ave
# Out:
#        beer_beerid                        beer_name  \
# 0                3                 Cactus Queen IPA
# 1                4         Wildcatter's Crude Stout
# 2                5                            Amber
# 3                6                         Turbodog
# 4                7                      Purple Haze
# ...            ...                              ...
# 66039        77313            Aass Gourmet Pale Ale
# 66040        77314  Betty Brown Norwegian Brwon Ale
# 66041        77315             Icelandic White Beer
# 66042        77316                 Crank Yanker IPA
# 66043        77317                      Belgo Sutra
#
#                         brewery_name              beer_style  brewery_id  \
# 0        Yellow Rose Brewing Company            American IPA         2.0
# 1        Yellow Rose Brewing Company          American Stout         2.0
# 2                  Abita Brewing Co.            Vienna Lager         3.0
# ...

# %%
beer_review_ave.to_csv('beer_review_ave.csv')
